# %% [markdown]
# ### Configurations

# %%
import pandas as pd
from players import *
from simulator import simulate_game

# %%
player1_list = [RandomPlayer(), NicePlayer(), GreedyPlayer(), FicklePlayer(), GrudgePlayer(), \
                CopycatPlayer(), SoreLoserPlayer(), CautiousPlayer(), CopykittenPlayer(), StrategicPlayer()]
player2_list = [RandomPlayer(), NicePlayer(), GreedyPlayer(), FicklePlayer(), GrudgePlayer(), \
                CopycatPlayer(), SoreLoserPlayer(), CautiousPlayer(), CopykittenPlayer(), StrategicPlayer()]

no_games = 100
pot = 1000
pool = 100
max_round = 10

# %%
def get_df_report(no_games):
    dict_list = []
    for player1 in player1_list:
        for player2 in player2_list:
            dict_list.append(get_results(player1, player2, no_games))
    return pd.DataFrame.from_dict(dict_list)


def get_player_matchup(df, player):
    print("Most earning against")
    display(get_matchup(df, player))
    print()
    print("Least earning against")
    display(get_matchup(df, player, advantage=-1))
    print()
    print("Most advantage against")
    display(get_matchup(df, player, metric='DifferenceMoney'))
    print()
    print("Most fair against")
    display(get_matchup(df, player, metric='DifferenceMoney', advantage=0))
    print()
    print("Least advantage against")
    display(get_matchup(df, player, metric='DifferenceMoney', advantage=-1))


def get_metric_matchup(df, metric, advantage):
    df_temp = pd.DataFrame(columns=['Player', 'Opponent', 'Win', 'Draw', 'Lose', 'PlayerMoney', 'OpponentMoney', \
                                    'DifferenceMoney'])
    for player1 in player1_list:
        df_temp = df_temp.append(get_matchup(df, player1.get_class(), metric, advantage), ignore_index=True)
    return df_temp
    

def get_results(player1, player2, no_games):
    results = {'Player': player1.get_class(), 'Opponent': player2.get_class(), 'Win': 0, 'Draw': 0, 'Lose': 0, \
               'PlayerMoney': 0, 'OpponentMoney': 0}
    for i in range(no_games):
        simulate_game(player1, player2, pot, pool, max_round)
        if player1.money == player2.money:
            results['Draw'] += 1
        elif player1.money > player2.money:
            results['Win'] += 1
        else:
            results['Lose'] += 1
        results['PlayerMoney'] += player1.money
        results['OpponentMoney'] += player2.money
    results['PlayerMoney'] /= no_games
    results['OpponentMoney'] /= no_games
    return results


def get_matchup(df, player, metric='PlayerMoney', advantage=1):
    dict_list = []
    df_temp = df.loc[df['Player'] == player]
    if advantage == 1:
        match = df_temp.loc[df_temp[metric] == df_temp[metric].max()].to_dict('records')
    elif advantage == 0:
        match = df_temp.loc[abs(df_temp[metric]) == abs(df_temp[metric]).min()].to_dict('records')
    else:
        match = df_temp.loc[df_temp[metric] == df_temp[metric].min()].to_dict('records')
    dict_list += match

    return pd.DataFrame.from_dict(dict_list)

# %% [markdown]
# ### Simulate game

# %%
df = get_df_report(no_games)
df['DifferenceMoney'] = df['PlayerMoney'] - df['OpponentMoney']
df.head()
# Out:
#          Player      Opponent  Win  Draw  Lose  PlayerMoney  OpponentMoney  \
# 0  RandomPlayer  RandomPlayer   41    18    41        380.0          369.0
# 1  RandomPlayer    NicePlayer  100     0     0        751.0          249.0
# 2  RandomPlayer  GreedyPlayer    0     0   100          0.0          476.0
# 3  RandomPlayer  FicklePlayer   38    29    33        380.5          364.5
# 4  RandomPlayer  GrudgePlayer    1     3    96        150.0          461.0
#
#    DifferenceMoney
# 0             11.0
# 1            502.0
# 2           -476.0
# 3             16.0
# 4           -311.0

# %% [markdown]
# ### Result

# %%
for player in player1_list:
    display(df.loc[df['Player'] == player.get_class()])
    print()
# Out:
#          Player          Opponent  Win  Draw  Lose  PlayerMoney  \
# 0  RandomPlayer      RandomPlayer   41    18    41        380.0
# 1  RandomPlayer        NicePlayer  100     0     0        751.0
# 2  RandomPlayer      GreedyPlayer    0     0   100          0.0
# 3  RandomPlayer      FicklePlayer   38    29    33        380.5
# 4  RandomPlayer      GrudgePlayer    1     3    96        150.0
# 5  RandomPlayer     CopycatPlayer   43    57     0        403.5
# 6  RandomPlayer   SoreLoserPlayer   52    48     0        416.0
# 7  RandomPlayer    CautiousPlayer    1     9    90        264.5
# 8  RandomPlayer  CopykittenPlayer   47    53     0        423.0
# 9  RandomPlayer   StrategicPlayer   73    16    11        442.5
#
#    OpponentMoney  DifferenceMoney
# 0          369.0             11.0
# 1          249.0            502.0
# 2          476.0           -476.0
# 3          364.5             16.0
# 4          461.0           -311.0
# 5          360.5             43.0
# 6          364.0             52.0
# 7          424.5           -160.0
# 8          375.0             48.0
# 9          346.5             96.0
#         Player          Opponent  Win  Draw  Lose  PlayerMoney  OpponentMoney  \
# 10  NicePlayer      RandomPlayer    0     0   100        263.5          736.5
# 11  NicePlayer        NicePlayer    0   100     0        500.0          500.0
# 12  NicePlayer      GreedyPlayer    0     0   100          0.0         1000.0
# 13  NicePlayer      FicklePlayer    0     0   100        250.0          750.0
# 14  NicePlayer      GrudgePlayer    0   100     0        500.0          500.0
# 15  NicePlayer     CopycatPlayer    0   100     0        500.0          500.0
# 16  NicePlayer   SoreLoserPlayer    0   100     0        500.0          500.0
# 17  NicePlayer    CautiousPlayer    0   100     0        500.0          500.0
# 18  NicePlayer  CopykittenPlayer    0   100     0        500.0          500.0
# 19  NicePlayer   StrategicPlayer    0     0   100        150.0          850.0
#
#     DifferenceMoney
# 10           -473.0
# 11              0.0
# 12          -1000.0
# 13           -500.0
# 14              0.0
# 15              0.0
# 16              0.0
# 17              0.0
# 18              0.0
# 19           -700.0
#           Player          Opponent  Win  Draw  Lose  PlayerMoney  \
# 20  GreedyPlayer      RandomPlayer  100     0     0        514.0
# 21  GreedyPlayer        NicePlayer  100     0     0       1000.0
# 22  GreedyPlayer      GreedyPlayer    0   100     0          0.0
# 23  GreedyPlayer      FicklePlayer  100     0     0        500.0
# 24  GreedyPlayer      GrudgePlayer  100     0     0        100.0
# 25  GreedyPlayer     CopycatPlayer  100     0     0        100.0
# 26  GreedyPlayer   SoreLoserPlayer  100     0     0        100.0
# 27  GreedyPlayer    CautiousPlayer  100     0     0        100.0
# 28  GreedyPlayer  CopykittenPlayer  100     0     0        100.0
# 29  GreedyPlayer   StrategicPlayer  100     0     0        300.0
#
#     OpponentMoney  DifferenceMoney
# 20            0.0            514.0
# 21            0.0           1000.0
# 22            0.0              0.0
# 23            0.0            500.0
# 24            0.0            100.0
# 25            0.0            100.0
# 26            0.0            100.0
# 27            0.0            100.0
# 28            0.0            100.0
# 29            0.0            300.0
#           Player          Opponent  Win  Draw  Lose  PlayerMoney  \
# 30  FicklePlayer      RandomPlayer   32    26    42        366.0
# 31  FicklePlayer        NicePlayer  100     0     0        750.0
# 32  FicklePlayer      GreedyPlayer    0     0   100          0.0
# 33  FicklePlayer      FicklePlayer    0   100     0        380.0
# 34  FicklePlayer      GrudgePlayer    0     0   100        121.0
# 35  FicklePlayer     CopycatPlayer   47    53     0        523.5
# 36  FicklePlayer   SoreLoserPlayer   45    55     0        522.5
# 37  FicklePlayer    CautiousPlayer    0     0   100        124.5
# 38  FicklePlayer  CopykittenPlayer   51    49     0        525.5
# 39  FicklePlayer   StrategicPlayer  100     0     0        524.5
#
#     OpponentMoney  DifferenceMoney
# 30          388.0            -22.0
# 31          250.0            500.0
# 32          500.0           -500.0
# 33          380.0              0.0
# 34          479.0           -358.0
# 35          476.5             47.0
# 36          477.5             45.0
# 37          475.5           -351.0
# 38          474.5             51.0
# 39          424.5            100.0
#           Player          Opponent  Win  Draw  Lose  PlayerMoney  \
# 40  GrudgePlayer      RandomPlayer   95     4     1        413.5
# 41  GrudgePlayer        NicePlayer    0   100     0        500.0
# 42  GrudgePlayer      GreedyPlayer    0     0   100          0.0
# 43  GrudgePlayer      FicklePlayer  100     0     0        478.5
# 44  GrudgePlayer      GrudgePlayer    0   100     0        500.0
# 45  GrudgePlayer     CopycatPlayer    0   100     0        500.0
# 46  GrudgePlayer   SoreLoserPlayer    0   100     0        500.0
# 47  GrudgePlayer    CautiousPlayer    0   100     0        500.0
# 48  GrudgePlayer  CopykittenPlayer    0   100     0        500.0
# 49  GrudgePlayer   StrategicPlayer  100     0     0        250.0
#
#     OpponentMoney  DifferenceMoney
# 40          150.5            263.0
# 41          500.0              0.0
# 42          100.0           -100.0
# 43          121.5            357.0
# 44          500.0              0.0
# 45          500.0              0.0
# 46          500.0              0.0
# 47          500.0              0.0
# 48          500.0              0.0
# 49          150.0            100.0
#            Player          Opponent  Win  Draw  Lose  PlayerMoney  \
# 50  CopycatPlayer      RandomPlayer    0    51    49        362.0
# 51  CopycatPlayer        NicePlayer    0   100     0        500.0
# 52  CopycatPlayer      GreedyPlayer    0     0   100          0.0
# 53  CopycatPlayer      FicklePlayer    0    51    49        475.5
# 54  CopycatPlayer      GrudgePlayer    0   100     0        500.0
# 55  CopycatPlayer     CopycatPlayer    0   100     0        500.0
# 56  CopycatPlayer   SoreLoserPlayer    0   100     0        500.0
# 57  CopycatPlayer    CautiousPlayer    0   100     0        500.0
# 58  CopycatPlayer  CopykittenPlayer    0   100     0        500.0
# 59  CopycatPlayer   StrategicPlayer    0   100     0        500.0
#
#     OpponentMoney  DifferenceMoney
# 50          411.0            -49.0
# 51          500.0              0.0
# 52          100.0           -100.0
# 53          524.5            -49.0
# 54          500.0              0.0
# 55          500.0              0.0
# 56          500.0              0.0
# 57          500.0              0.0
# 58          500.0              0.0
# 59          500.0              0.0
#              Player          Opponent  Win  Draw  Lose  PlayerMoney  \
# 60  SoreLoserPlayer      RandomPlayer    0    55    45        371.5
# 61  SoreLoserPlayer        NicePlayer    0   100     0        500.0
# 62  SoreLoserPlayer      GreedyPlayer    0     0   100          0.0
# 63  SoreLoserPlayer      FicklePlayer    0    55    45        477.5
# 64  SoreLoserPlayer      GrudgePlayer    0   100     0        500.0
# 65  SoreLoserPlayer     CopycatPlayer    0   100     0        500.0
# 66  SoreLoserPlayer   SoreLoserPlayer    0   100     0        500.0
# 67  SoreLoserPlayer    CautiousPlayer    0   100     0        500.0
# 68  SoreLoserPlayer  CopykittenPlayer    0   100     0        500.0
# 69  SoreLoserPlayer   StrategicPlayer    0   100     0        500.0
#
#     OpponentMoney  DifferenceMoney
# 60          416.5            -45.0
# 61          500.0              0.0
# 62          100.0           -100.0
# 63          522.5            -45.0
# 64          500.0              0.0
# 65          500.0              0.0
# 66          500.0              0.0
# 67          500.0              0.0
# 68          500.0              0.0
# 69          500.0              0.0
#             Player          Opponent  Win  Draw  Lose  PlayerMoney  \
# 70  CautiousPlayer      RandomPlayer   85    13     2        433.5
# 71  CautiousPlayer        NicePlayer    0   100     0        500.0
# 72  CautiousPlayer      GreedyPlayer    0     0   100          0.0
# 73  CautiousPlayer      FicklePlayer  100     0     0        472.5
# 74  CautiousPlayer      GrudgePlayer    0   100     0        500.0
# 75  CautiousPlayer     CopycatPlayer    0   100     0        500.0
# 76  CautiousPlayer   SoreLoserPlayer    0   100     0        500.0
# 77  CautiousPlayer    CautiousPlayer    0   100     0        500.0
# 78  CautiousPlayer  CopykittenPlayer    0   100     0        500.0
# 79  CautiousPlayer   StrategicPlayer  100     0     0        350.0
#
#     OpponentMoney  DifferenceMoney
# 70          294.5            139.0
# 71          500.0              0.0
# 72          100.0           -100.0
# 73          127.5            345.0
# 74          500.0              0.0
# 75          500.0              0.0
# 76          500.0              0.0
# 77          500.0              0.0
# 78          500.0              0.0
# 79          250.0            100.0
#               Player          Opponent  Win  Draw  Lose  PlayerMoney  \
# 80  CopykittenPlayer      RandomPlayer    0    50    50        353.5
# 81  CopykittenPlayer        NicePlayer    0   100     0        500.0
# 82  CopykittenPlayer      GreedyPlayer    0     0   100          0.0
# 83  CopykittenPlayer      FicklePlayer    0    48    52        474.0
# 84  CopykittenPlayer      GrudgePlayer    0   100     0        500.0
# 85  CopykittenPlayer     CopycatPlayer    0   100     0        500.0
# 86  CopykittenPlayer   SoreLoserPlayer    0   100     0        500.0
# 87  CopykittenPlayer    CautiousPlayer    0   100     0        500.0
# 88  CopykittenPlayer  CopykittenPlayer    0   100     0        500.0
# 89  CopykittenPlayer   StrategicPlayer    0   100     0        500.0
#
#     OpponentMoney  DifferenceMoney
# 80          403.5            -50.0
# 81          500.0              0.0
# 82          100.0           -100.0
# 83          526.0            -52.0
# 84          500.0              0.0
# 85          500.0              0.0
# 86          500.0              0.0
# 87          500.0              0.0
# 88          500.0              0.0
# 89          500.0              0.0
#              Player          Opponent  Win  Draw  Lose  PlayerMoney  \
# 90  StrategicPlayer      RandomPlayer   15    24    61        372.0
# 91  StrategicPlayer        NicePlayer  100     0     0        850.0
# 92  StrategicPlayer      GreedyPlayer    0     0   100          0.0
# 93  StrategicPlayer      FicklePlayer    0     0   100        425.0
# 94  StrategicPlayer      GrudgePlayer    0     0   100        150.0
# 95  StrategicPlayer     CopycatPlayer    0   100     0        500.0
# 96  StrategicPlayer   SoreLoserPlayer    0   100     0        500.0
# 97  StrategicPlayer    CautiousPlayer    0     0   100        250.0
# 98  StrategicPlayer  CopykittenPlayer    0   100     0        500.0
# 99  StrategicPlayer   StrategicPlayer    0   100     0        450.0
#
#     OpponentMoney  DifferenceMoney
# 90          434.0            -62.0
# 91          150.0            700.0
# 92          300.0           -300.0
# 93          525.0           -100.0
# 94          250.0           -100.0
# 95          500.0              0.0
# 96          500.0              0.0
# 97          350.0           -100.0
# 98          500.0              0.0
# 99          450.0              0.0

# %% [markdown]
# ### Average

# %%
# Win
df.groupby('Player').mean().sort_values(by=['Win'], ascending=False)
# Out:
#                    Win  Draw  Lose  PlayerMoney  OpponentMoney  \
# Player
# GreedyPlayer      90.0  10.0   0.0       281.40           0.00
# RandomPlayer      39.6  23.3  37.1       361.10         379.00
# FicklePlayer      37.5  28.3  34.2       383.75         432.55
# GrudgePlayer      29.5  60.4  10.1       414.20         352.20
# CautiousPlayer    28.5  61.3  10.2       425.60         377.20
# StrategicPlayer   11.5  42.4  46.1       399.70         395.90
# CopycatPlayer      0.0  80.2  19.8       433.75         453.55
# CopykittenPlayer   0.0  79.8  20.2       432.75         452.95
# NicePlayer         0.0  60.0  40.0       366.35         633.65
# SoreLoserPlayer    0.0  81.0  19.0       434.90         453.90
#
#                   DifferenceMoney
# Player
# GreedyPlayer                281.4
# RandomPlayer                -17.9
# FicklePlayer                -48.8
# GrudgePlayer                 62.0
# CautiousPlayer               48.4
# StrategicPlayer               3.8
# CopycatPlayer               -19.8
# CopykittenPlayer            -20.2
# NicePlayer                 -267.3
# SoreLoserPlayer             -19.0

# %%
# Draw
df.groupby('Player').mean().sort_values(by=['Draw'], ascending=False)
# Out:
#                    Win  Draw  Lose  PlayerMoney  OpponentMoney  \
# Player
# SoreLoserPlayer    0.0  81.0  19.0       434.90         453.90
# CopycatPlayer      0.0  80.2  19.8       433.75         453.55
# CopykittenPlayer   0.0  79.8  20.2       432.75         452.95
# CautiousPlayer    28.5  61.3  10.2       425.60         377.20
# GrudgePlayer      29.5  60.4  10.1       414.20         352.20
# NicePlayer         0.0  60.0  40.0       366.35         633.65
# StrategicPlayer   11.5  42.4  46.1       399.70         395.90
# FicklePlayer      37.5  28.3  34.2       383.75         432.55
# RandomPlayer      39.6  23.3  37.1       361.10         379.00
# GreedyPlayer      90.0  10.0   0.0       281.40           0.00
#
#                   DifferenceMoney
# Player
# SoreLoserPlayer             -19.0
# CopycatPlayer               -19.8
# CopykittenPlayer            -20.2
# CautiousPlayer               48.4
# GrudgePlayer                 62.0
# NicePlayer                 -267.3
# StrategicPlayer               3.8
# FicklePlayer                -48.8
# RandomPlayer                -17.9
# GreedyPlayer                281.4

# %%
# Lose
df.groupby('Player').mean().sort_values(by=['Lose'], ascending=False)
# Out:
#                    Win  Draw  Lose  PlayerMoney  OpponentMoney  \
# Player
# StrategicPlayer   11.5  42.4  46.1       399.70         395.90
# NicePlayer         0.0  60.0  40.0       366.35         633.65
# RandomPlayer      39.6  23.3  37.1       361.10         379.00
# FicklePlayer      37.5  28.3  34.2       383.75         432.55
# CopykittenPlayer   0.0  79.8  20.2       432.75         452.95
# CopycatPlayer      0.0  80.2  19.8       433.75         453.55
# SoreLoserPlayer    0.0  81.0  19.0       434.90         453.90
# CautiousPlayer    28.5  61.3  10.2       425.60         377.20
# GrudgePlayer      29.5  60.4  10.1       414.20         352.20
# GreedyPlayer      90.0  10.0   0.0       281.40           0.00
#
#                   DifferenceMoney
# Player
# StrategicPlayer               3.8
# NicePlayer                 -267.3
# RandomPlayer                -17.9
# FicklePlayer                -48.8
# CopykittenPlayer            -20.2
# CopycatPlayer               -19.8
# SoreLoserPlayer             -19.0
# CautiousPlayer               48.4
# GrudgePlayer                 62.0
# GreedyPlayer                281.4

# %%
# Player money
df.groupby('Player').mean().sort_values(by=['PlayerMoney'], ascending=False)
# Out:
#                    Win  Draw  Lose  PlayerMoney  OpponentMoney  \
# Player
# SoreLoserPlayer    0.0  81.0  19.0       434.90         453.90
# CopycatPlayer      0.0  80.2  19.8       433.75         453.55
# CopykittenPlayer   0.0  79.8  20.2       432.75         452.95
# CautiousPlayer    28.5  61.3  10.2       425.60         377.20
# GrudgePlayer      29.5  60.4  10.1       414.20         352.20
# StrategicPlayer   11.5  42.4  46.1       399.70         395.90
# FicklePlayer      37.5  28.3  34.2       383.75         432.55
# NicePlayer         0.0  60.0  40.0       366.35         633.65
# RandomPlayer      39.6  23.3  37.1       361.10         379.00
# GreedyPlayer      90.0  10.0   0.0       281.40           0.00
#
#                   DifferenceMoney
# Player
# SoreLoserPlayer             -19.0
# CopycatPlayer               -19.8
# CopykittenPlayer            -20.2
# CautiousPlayer               48.4
# GrudgePlayer                 62.0
# StrategicPlayer               3.8
# FicklePlayer                -48.8
# NicePlayer                 -267.3
# RandomPlayer                -17.9
# GreedyPlayer                281.4

# %%
# Opponent money
df.groupby('Player').mean().sort_values(by=['OpponentMoney'], ascending=False)
# Out:
#                    Win  Draw  Lose  PlayerMoney  OpponentMoney  \
# Player
# NicePlayer         0.0  60.0  40.0       366.35         633.65
# SoreLoserPlayer    0.0  81.0  19.0       434.90         453.90
# CopycatPlayer      0.0  80.2  19.8       433.75         453.55
# CopykittenPlayer   0.0  79.8  20.2       432.75         452.95
# FicklePlayer      37.5  28.3  34.2       383.75         432.55
# StrategicPlayer   11.5  42.4  46.1       399.70         395.90
# RandomPlayer      39.6  23.3  37.1       361.10         379.00
# CautiousPlayer    28.5  61.3  10.2       425.60         377.20
# GrudgePlayer      29.5  60.4  10.1       414.20         352.20
# GreedyPlayer      90.0  10.0   0.0       281.40           0.00
#
#                   DifferenceMoney
# Player
# NicePlayer                 -267.3
# SoreLoserPlayer             -19.0
# CopycatPlayer               -19.8
# CopykittenPlayer            -20.2
# FicklePlayer                -48.8
# StrategicPlayer               3.8
# RandomPlayer                -17.9
# CautiousPlayer               48.4
# GrudgePlayer                 62.0
# GreedyPlayer                281.4

# %%
# Difference in player money and opponent money
df.groupby('Player').mean().sort_values(by=['DifferenceMoney'], ascending=False)
# Out:
#                    Win  Draw  Lose  PlayerMoney  OpponentMoney  \
# Player
# GreedyPlayer      90.0  10.0   0.0       281.40           0.00
# GrudgePlayer      29.5  60.4  10.1       414.20         352.20
# CautiousPlayer    28.5  61.3  10.2       425.60         377.20
# StrategicPlayer   11.5  42.4  46.1       399.70         395.90
# RandomPlayer      39.6  23.3  37.1       361.10         379.00
# SoreLoserPlayer    0.0  81.0  19.0       434.90         453.90
# CopycatPlayer      0.0  80.2  19.8       433.75         453.55
# CopykittenPlayer   0.0  79.8  20.2       432.75         452.95
# FicklePlayer      37.5  28.3  34.2       383.75         432.55
# NicePlayer         0.0  60.0  40.0       366.35         633.65
#
#                   DifferenceMoney
# Player
# GreedyPlayer                281.4
# GrudgePlayer                 62.0
# CautiousPlayer               48.4
# StrategicPlayer               3.8
# RandomPlayer                -17.9
# SoreLoserPlayer             -19.0
# CopycatPlayer               -19.8
# CopykittenPlayer            -20.2
# FicklePlayer                -48.8
# NicePlayer                 -267.3

# %% [markdown]
# ### Player match up

# %%
get_player_matchup(df, 'RandomPlayer')
# Out:
# Most earning against
#          Player    Opponent  Win  Draw  Lose  PlayerMoney  OpponentMoney  \
# 0  RandomPlayer  NicePlayer  100     0     0        751.0          249.0
#
#    DifferenceMoney
# 0            502.0
# Least earning against
#          Player      Opponent  Win  Draw  Lose  PlayerMoney  OpponentMoney  \
# 0  RandomPlayer  GreedyPlayer    0     0   100          0.0          476.0
#
#    DifferenceMoney
# 0           -476.0
# Most advantage against
#          Player    Opponent  Win  Draw  Lose  PlayerMoney  OpponentMoney  \
# 0  RandomPlayer  NicePlayer  100     0     0        751.0          249.0
#
#    DifferenceMoney
# 0            502.0
# Most fair against
#          Player      Opponent  Win  Draw  Lose  PlayerMoney  OpponentMoney  \
# 0  RandomPlayer  RandomPlayer   41    18    41        380.0          369.0
#
#    DifferenceMoney
# 0             11.0
# Least advantage against
#          Player      Opponent  Win  Draw  Lose  PlayerMoney  OpponentMoney  \
# 0  RandomPlayer  GreedyPlayer    0     0   100          0.0          476.0
#
#    DifferenceMoney
# 0           -476.0

# %% [markdown]
# ### Metric match up

# %%
# Most earning against
get_metric_matchup(df, 'PlayerMoney', 1)
# Out:
#               Player          Opponent  Win Draw Lose  PlayerMoney  \
# 0       RandomPlayer        NicePlayer  100    0    0        751.0
# 1         NicePlayer        NicePlayer    0  100    0        500.0
# 2         NicePlayer      GrudgePlayer    0  100    0        500.0
# 3         NicePlayer     CopycatPlayer    0  100    0        500.0
# 4         NicePlayer   SoreLoserPlayer    0  100    0        500.0
# 5         NicePlayer    CautiousPlayer    0  100    0        500.0
# 6         NicePlayer  CopykittenPlayer    0  100    0        500.0
# 7       GreedyPlayer        NicePlayer  100    0    0       1000.0
# 8       FicklePlayer        NicePlayer  100    0    0        750.0
# 9       GrudgePlayer        NicePlayer    0  100    0        500.0
# 10      GrudgePlayer      GrudgePlayer    0  100    0        500.0
# 11      GrudgePlayer     CopycatPlayer    0  100    0        500.0
# 12      GrudgePlayer   SoreLoserPlayer    0  100    0        500.0
# 13      GrudgePlayer    CautiousPlayer    0  100    0        500.0
# 14      GrudgePlayer  CopykittenPlayer    0  100    0        500.0
# 15     CopycatPlayer        NicePlayer    0  100    0        500.0
# 16     CopycatPlayer      GrudgePlayer    0  100    0        500.0
# 17     CopycatPlayer     CopycatPlayer    0  100    0        500.0
# 18     CopycatPlayer   SoreLoserPlayer    0  100    0        500.0
# 19     CopycatPlayer    CautiousPlayer    0  100    0        500.0
# 20     CopycatPlayer  CopykittenPlayer    0  100    0        500.0
# 21     CopycatPlayer   StrategicPlayer    0  100    0        500.0
# 22   SoreLoserPlayer        NicePlayer    0  100    0        500.0
# 23   SoreLoserPlayer      GrudgePlayer    0  100    0        500.0
# 24   SoreLoserPlayer     CopycatPlayer    0  100    0        500.0
# 25   SoreLoserPlayer   SoreLoserPlayer    0  100    0        500.0
# 26   SoreLoserPlayer    CautiousPlayer    0  100    0        500.0
# 27   SoreLoserPlayer  CopykittenPlayer    0  100    0        500.0
# 28   SoreLoserPlayer   StrategicPlayer    0  100    0        500.0
# 29    CautiousPlayer        NicePlayer    0  100    0        500.0
# 30    CautiousPlayer      GrudgePlayer    0  100    0        500.0
# 31    CautiousPlayer     CopycatPlayer    0  100    0        500.0
# 32    CautiousPlayer   SoreLoserPlayer    0  100    0        500.0
# 33    CautiousPlayer    CautiousPlayer    0  100    0        500.0
# 34    CautiousPlayer  CopykittenPlayer    0  100    0        500.0
# 35  CopykittenPlayer        NicePlayer    0  100    0        500.0
# 36  CopykittenPlayer      GrudgePlayer    0  100    0        500.0
# 37  CopykittenPlayer     CopycatPlayer    0  100    0        500.0
# 38  CopykittenPlayer   SoreLoserPlayer    0  100    0        500.0
# 39  CopykittenPlayer    CautiousPlayer    0  100    0        500.0
# 40  CopykittenPlayer  CopykittenPlayer    0  100    0        500.0
# 41  CopykittenPlayer   StrategicPlayer    0  100    0        500.0
# 42   StrategicPlayer        NicePlayer  100    0    0        850.0
#
#     OpponentMoney  DifferenceMoney
# 0           249.0            502.0
# 1           500.0              0.0
# 2           500.0              0.0
# 3           500.0              0.0
# 4           500.0              0.0
# 5           500.0              0.0
# 6           500.0              0.0
# 7             0.0           1000.0
# 8           250.0            500.0
# 9           500.0              0.0
# 10          500.0              0.0
# 11          500.0              0.0
# 12          500.0              0.0
# 13          500.0              0.0
# 14          500.0              0.0
# 15          500.0              0.0
# 16          500.0              0.0
# 17          500.0              0.0
# 18          500.0              0.0
# 19          500.0              0.0
# 20          500.0              0.0
# 21          500.0              0.0
# 22          500.0              0.0
# 23          500.0              0.0
# 24          500.0              0.0
# 25          500.0              0.0
# 26          500.0              0.0
# 27          500.0              0.0
# 28          500.0              0.0
# 29          500.0              0.0
# 30          500.0              0.0
# 31          500.0              0.0
# 32          500.0              0.0
# 33          500.0              0.0
# 34          500.0              0.0
# 35          500.0              0.0
# 36          500.0              0.0
# 37          500.0              0.0
# 38          500.0              0.0
# 39          500.0              0.0
# 40          500.0              0.0
# 41          500.0              0.0
# 42          150.0            700.0
